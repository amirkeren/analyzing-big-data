# %%
filename = 'user-ct-test-collection-01.txt'

# %%
import urllib
import os
import gzip
import shutil

if os.path.isfile(filename):
    print 'Dataset found'
else:
    print 'Downloading dataset'
    urllib.urlretrieve('https://github.com/dimosr/Big_Data/raw/master/resources/user-ct-test-collection-01.txt.gz', filename + '.gz')
    print 'Download complete, unzipping'
    with gzip.open(filename + '.gz', 'rb') as f_in:
        with open(filename, 'wb') as f_out:
            shutil.copyfileobj(f_in, f_out)
    os.remove(filename + '.gz')        
    print 'Unzip complete'
# Out:
# Downloading dataset
# Download complete, unzipping
# Unzip complete

# %%
# REMOVE THIS AFTER TESTING
# !head -1000 user-ct-test-collection-01.txt > user-ct-test-collection-01.txt.cpy
# !mv user-ct-test-collection-01.txt.cpy user-ct-test-collection-01.txt

# %%
import pandas as pd

df = pd.read_csv(filename, sep='\t')
df
# Out:
#      AnonID                               Query            QueryTime  \
# 0       142                      rentdirect.com  2006-03-01 07:17:12
# 1       142         www.prescriptionfortime.com  2006-03-12 12:31:06
# 2       142                          staple.com  2006-03-17 21:19:29
# 3       142                          staple.com  2006-03-17 21:19:45
# 4       142           www.newyorklawyersite.com  2006-03-18 08:02:58
# 5       142           www.newyorklawyersite.com  2006-03-18 08:03:09
# 6       142                     westchester.gov  2006-03-20 03:55:57
# 7       142                       space.comhttp  2006-03-24 20:51:24
# 8       142                                dfdf  2006-03-24 22:23:07
# 9       142                                dfdf  2006-03-24 22:23:14
# 10      142                         vaniqa.comh  2006-03-25 23:27:12
# 11      142                 www.collegeucla.edu  2006-04-03 21:12:14
# 12      142                          www.elaorg  2006-04-03 21:25:20
# 13      142                        207 ad2d 530  2006-04-08 01:31:04
# 14      142                        207 ad2d 530  2006-04-08 01:31:14
# 15      142                   broadway.vera.org  2006-04-08 08:38:23
# 16      142                   broadway.vera.org  2006-04-08 08:38:31
# 17      142                            vera.org  2006-04-08 08:38:42
# 18      142                   broadway.vera.org  2006-04-08 08:39:30
# 19      142                    frankmellace.com  2006-04-09 02:19:24
# 20      142                         ucs.ljx.com  2006-04-09 02:20:44
# 21      142                   attornyleslie.com  2006-04-13 00:25:27
# 22      142            merit release appearance  2006-04-22 23:51:18
# 23      142                 www.bonsai.wbff.org  2006-05-06 08:49:34
# 24      142                         loislaw.com  2006-05-12 22:43:36
# 25      142                           rapny.com  2006-05-18 09:21:57
# 26      142                      whitepages.com  2006-05-19 19:36:31
# 27      217                             lottery  2006-03-01 11:58:51
# 28      217                             lottery  2006-03-01 11:58:51
# 29      217                      ameriprise.com  2006-03-01 14:06:23
# ..      ...                                 ...                  ...
# 969    2722            aartstranscript.army.mil  2006-05-18 12:22:00
# 970    2722                       cool.army.mil  2006-05-18 12:30:30
# 971    2722                           .army.mil  2006-05-18 12:32:36
# 972    2722                            army.mil  2006-05-18 12:33:20
# 973    2722                            army.mil  2006-05-18 12:33:20
# 974    2722        george washington university  2006-05-18 12:43:56
# 975    2722                  st philips college  2006-05-18 12:55:06
# 976    2722           georgia perimeter college  2006-05-18 13:00:37
# 977    2722                            goodyear  2006-05-21 09:10:59
# 978    2722                          hyundaiusa  2006-05-21 09:28:54
# 979    2722                 order hyundai parts  2006-05-21 09:51:02
# 980    2722                 order hyundai parts  2006-05-21 09:51:02
# 981    2722                 order hyundai parts  2006-05-21 09:51:02
# 982    2722                     napa aotu parts  2006-05-21 10:44:29
# 983    2722                     napa auto parts  2006-05-21 10:45:02
# 984    2722                         j c whitney  2006-05-21 10:54:21
# 985    2722            shift knob pattern plate  2006-05-21 10:55:54
# 986    2722                         atozone com  2006-05-21 11:31:36
# 987    2722                        autozone com  2006-05-21 11:31:44
# 988    2722                        autozone com  2006-05-21 11:31:44
# 989    2722                  advance auto parts  2006-05-21 11:47:17
# 990    2722  how to remove adware from computer  2006-05-21 15:23:09
# 991    2722                             mailbox  2006-05-23 00:08:39
# 992    2722                             mailbox  2006-05-23 00:08:42
# 993    2722                          jc whitney  2006-05-23 00:25:47
# 994    2722          new a c for hyndai elantra  2006-05-23 00:32:13
# 995    2722         new a c for hyundai elantra  2006-05-23 00:34:57
# 996    2722         recalls for hyundai elantra  2006-05-23 00:37:16
# 997    2722               meadow creek football  2006-05-23 15:12:00
# 998    2722         meadow creek youth football  2006-05-23 15:12:46
#
#      ItemRank                           ClickURL
# 0         NaN                                NaN
# 1         NaN                                NaN
# 2         NaN                                NaN
# 3         NaN                                NaN
# 4         NaN                                NaN
# 5         NaN                                NaN
# 6         1.0      http://www.westchestergov.com
# 7         NaN                                NaN
# 8         NaN                                NaN
# 9         NaN                                NaN
# 10        NaN                                NaN
# 11        NaN                                NaN
# 12        NaN                                NaN
# 13        NaN                                NaN
# 14        1.0      http://www.courts.state.ny.us
# 15        NaN                                NaN
# 16        NaN                                NaN
# 17        1.0                http://www.vera.org
# 18        NaN                                NaN
# 19        NaN                                NaN
# 20        NaN                                NaN
# 21        NaN                                NaN
# 22        NaN                                NaN
# 23        NaN                                NaN
# 24        NaN                                NaN
# 25        NaN                                NaN
# 26        NaN                                NaN
# 27        1.0           http://www.calottery.com
# 28        1.0           http://www.calottery.com
# 29        1.0          http://www.ameriprise.com
# ..        ...                                ...
# 969       1.0  https://aartstranscript.army.mil/
# 970       NaN                                NaN
# 971       NaN                                NaN
# 972       1.0                http://www.army.mil
# 973       1.0                http://www.army.mil
# 974       1.0                 http://www.gwu.edu
# 975       1.0                http://www.accd.edu
# 976       1.0                 http://www.gpc.edu
# 977       1.0            http://www.goodyear.com
# 978       1.0          http://www.hyundaiusa.com
# 979       2.0    http://www.hypartswholesale.com
# 980       9.0     http://www.the-best-source.com
# 981       6.0           http://www.racepages.com
# 982       NaN                                NaN
# 983       1.0          http://www.napaonline.com
# 984       NaN                                NaN
# 985       NaN                                NaN
# 986       NaN                                NaN
# 987       1.0            http://www.autozone.com
# 988       1.0            http://www.autozone.com
# 989       1.0    http://www.advanceautoparts.com
# 990       1.0           http://www.microsoft.com
# 991       NaN                                NaN
# 992       NaN                                NaN
# 993       1.0           http://www.jcwhitney.com
# 994       NaN                                NaN
# 995       1.0          http://www.partstrain.com
# 996       1.0   http://www.internetautoguide.com
# 997       NaN                                NaN
# 998       NaN                                NaN
#
# [999 rows x 5 columns]

# %%
grouped = df.groupby('AnonID')
for name, group in grouped:
    print '===================='
    print         name
    print '===================='
    filtered['TimeStamp'] = filtered['QueryTime'].map(lambda x: pd.Timestamp(x))
    filtered.set_index('TimeStamp', inplace=True)
    windows = [g for n, g in filtered.groupby(pd.TimeGrouper('10Min'))]
    for window in windows:
        if not window.empty:
            print window.Query.values
# Out:
# ====================
# 142
# ====================
# /home/amir/.local/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ['rentdirect.com']
# ['www.prescriptionfortime.com']
# ['staple.com' 'staple.com']
# ['www.newyorklawyersite.com' 'www.newyorklawyersite.com']
# ['westchester.gov']
# ['space.comhttp']
# ['dfdf' 'dfdf']
# ['vaniqa.comh']
# ['www.collegeucla.edu']
# ['www.elaorg']
# ['207 ad2d 530' '207 ad2d 530']
# ['broadway.vera.org' 'broadway.vera.org' 'vera.org' 'broadway.vera.org']
# ['frankmellace.com']
# ['ucs.ljx.com']
# ['attornyleslie.com']
# ['merit release appearance']
# ['www.bonsai.wbff.org']
# ['loislaw.com']
# ['rapny.com']
# ['whitepages.com']
# ====================
# 217
# ====================
# ['rentdirect.com']
# ['www.prescriptionfortime.com']
# ['staple.com' 'staple.com']
# ['www.newyorklawyersite.com' 'www.newyorklawyersite.com']
# ['westchester.gov']
# ['space.comhttp']
# ['dfdf' 'dfdf']
# ['vaniqa.comh']
# ['www.collegeucla.edu']
# ['www.elaorg']
# ['207 ad2d 530' '207 ad2d 530']
# ['broadway.vera.org' 'broadway.vera.org' 'vera.org' 'broadway.vera.org']
# ['frankmellace.com']
# ['ucs.ljx.com']
# ['attornyleslie.com']
# ['merit release appearance']
# ['www.bonsai.wbff.org']
# ['loislaw.com']
# ['rapny.com']
# ['whitepages.com']
# ====================
# 993
# ====================
# ['rentdirect.com']
# ['www.prescriptionfortime.com']
# ['staple.com' 'staple.com']
# ['www.newyorklawyersite.com' 'www.newyorklawyersite.com']
# ['westchester.gov']
# ['space.comhttp']
# ['dfdf' 'dfdf']
# ['vaniqa.comh']
# ['www.collegeucla.edu']
# ['www.elaorg']
# ['207 ad2d 530' '207 ad2d 530']
# ['broadway.vera.org' 'broadway.vera.org' 'vera.org' 'broadway.vera.org']
# ['frankmellace.com']
# ['ucs.ljx.com']
# ['attornyleslie.com']
# ['merit release appearance']
# ['www.bonsai.wbff.org']
# ['loislaw.com']
# ['rapny.com']
# ['whitepages.com']
# ====================
# 1268
# ====================
# ['rentdirect.com']
# ['www.prescriptionfortime.com']
# ['staple.com' 'staple.com']
# ['www.newyorklawyersite.com' 'www.newyorklawyersite.com']
# ['westchester.gov']
# ['space.comhttp']
# ['dfdf' 'dfdf']
# ['vaniqa.comh']
# ['www.collegeucla.edu']
# ['www.elaorg']
# ['207 ad2d 530' '207 ad2d 530']
# ['broadway.vera.org' 'broadway.vera.org' 'vera.org' 'broadway.vera.org']
# ['frankmellace.com']
# ['ucs.ljx.com']
# ['attornyleslie.com']
# ['merit release appearance']
# ['www.bonsai.wbff.org']
# ['loislaw.com']
# ['rapny.com']
# ['whitepages.com']
# ====================
# 1326
# ====================
# ['rentdirect.com']
# ['www.prescriptionfortime.com']
# ['staple.com' 'staple.com']
# ['www.newyorklawyersite.com' 'www.newyorklawyersite.com']
# ['westchester.gov']
# ['space.comhttp']
# ['dfdf' 'dfdf']
# ['vaniqa.comh']
# ['www.collegeucla.edu']
# ['www.elaorg']
# ['207 ad2d 530' '207 ad2d 530']
# ['broadway.vera.org' 'broadway.vera.org' 'vera.org' 'broadway.vera.org']
# ['frankmellace.com']
# ['ucs.ljx.com']
# ['attornyleslie.com']
# ['merit release appearance']
# ['www.bonsai.wbff.org']
# ['loislaw.com']
# ['rapny.com']
# ['whitepages.com']
# ====================
# 1337
# ====================
# ['rentdirect.com']
# ['www.prescriptionfortime.com']
# ['staple.com' 'staple.com']
# ['www.newyorklawyersite.com' 'www.newyorklawyersite.com']
# ['westchester.gov']
# ['space.comhttp']
# ['dfdf' 'dfdf']
# ['vaniqa.comh']
# ['www.collegeucla.edu']
# ['www.elaorg']
# ['207 ad2d 530' '207 ad2d 530']
# ['broadway.vera.org' 'broadway.vera.org' 'vera.org' 'broadway.vera.org']
# ['frankmellace.com']
# ['ucs.ljx.com']
# ['attornyleslie.com']
# ['merit release appearance']
# ['www.bonsai.wbff.org']
# ['loislaw.com']
# ['rapny.com']
# ['whitepages.com']
# ====================
# 1410
# ====================
# ['rentdirect.com']
# ['www.prescriptionfortime.com']
# ['staple.com' 'staple.com']
# ['www.newyorklawyersite.com' 'www.newyorklawyersite.com']
# ['westchester.gov']
# ['space.comhttp']
# ['dfdf' 'dfdf']
# ['vaniqa.comh']
# ['www.collegeucla.edu']
# ['www.elaorg']
# ['207 ad2d 530' '207 ad2d 530']
# ['broadway.vera.org' 'broadway.vera.org' 'vera.org' 'broadway.vera.org']
# ['frankmellace.com']
# ['ucs.ljx.com']
# ['attornyleslie.com']
# ['merit release appearance']
# ['www.bonsai.wbff.org']
# ['loislaw.com']
# ['rapny.com']
# ['whitepages.com']
# ====================
# 2005
# ====================
# ['rentdirect.com']
# ['www.prescriptionfortime.com']
# ['staple.com' 'staple.com']
# ['www.newyorklawyersite.com' 'www.newyorklawyersite.com']
# ['westchester.gov']
# ['space.comhttp']
# ['dfdf' 'dfdf']
# ['vaniqa.comh']
# ['www.collegeucla.edu']
# ['www.elaorg']
# ['207 ad2d 530' '207 ad2d 530']
# ['broadway.vera.org' 'broadway.vera.org' 'vera.org' 'broadway.vera.org']
# ['frankmellace.com']
# ['ucs.ljx.com']
# ['attornyleslie.com']
# ['merit release appearance']
# ['www.bonsai.wbff.org']
# ['loislaw.com']
# ['rapny.com']
# ['whitepages.com']
# ====================
# 2178
# ====================
# ['rentdirect.com']
# ['www.prescriptionfortime.com']
# ['staple.com' 'staple.com']
# ['www.newyorklawyersite.com' 'www.newyorklawyersite.com']
# ['westchester.gov']
# ['space.comhttp']
# ['dfdf' 'dfdf']
# ['vaniqa.comh']
# ['www.collegeucla.edu']
# ['www.elaorg']
# ['207 ad2d 530' '207 ad2d 530']
# ['broadway.vera.org' 'broadway.vera.org' 'vera.org' 'broadway.vera.org']
# ['frankmellace.com']
# ['ucs.ljx.com']
# ['attornyleslie.com']
# ['merit release appearance']
# ['www.bonsai.wbff.org']
# ['loislaw.com']
# ['rapny.com']
# ['whitepages.com']
# ====================
# 2334
# ====================
# ['rentdirect.com']
# ['www.prescriptionfortime.com']
# ['staple.com' 'staple.com']
# ['www.newyorklawyersite.com' 'www.newyorklawyersite.com']
# ['westchester.gov']
# ['space.comhttp']
# ['dfdf' 'dfdf']
# ['vaniqa.comh']
# ['www.collegeucla.edu']
# ['www.elaorg']
# ['207 ad2d 530' '207 ad2d 530']
# ['broadway.vera.org' 'broadway.vera.org' 'vera.org' 'broadway.vera.org']
# ['frankmellace.com']
# ['ucs.ljx.com']
# ['attornyleslie.com']
# ['merit release appearance']
# ['www.bonsai.wbff.org']
# ['loislaw.com']
# ['rapny.com']
# ['whitepages.com']
# ====================
# 2421
# ====================
# ['rentdirect.com']
# ['www.prescriptionfortime.com']
# ['staple.com' 'staple.com']
# ['www.newyorklawyersite.com' 'www.newyorklawyersite.com']
# ['westchester.gov']
# ['space.comhttp']
# ['dfdf' 'dfdf']
# ['vaniqa.comh']
# ['www.collegeucla.edu']
# ['www.elaorg']
# ['207 ad2d 530' '207 ad2d 530']
# ['broadway.vera.org' 'broadway.vera.org' 'vera.org' 'broadway.vera.org']
# ['frankmellace.com']
# ['ucs.ljx.com']
# ['attornyleslie.com']
# ['merit release appearance']
# ['www.bonsai.wbff.org']
# ['loislaw.com']
# ['rapny.com']
# ['whitepages.com']
# ====================
# 2465
# ====================
# ['rentdirect.com']
# ['www.prescriptionfortime.com']
# ['staple.com' 'staple.com']
# ['www.newyorklawyersite.com' 'www.newyorklawyersite.com']
# ['westchester.gov']
# ['space.comhttp']
# ['dfdf' 'dfdf']
# ['vaniqa.comh']
# ['www.collegeucla.edu']
# ['www.elaorg']
# ['207 ad2d 530' '207 ad2d 530']
# ['broadway.vera.org' 'broadway.vera.org' 'vera.org' 'broadway.vera.org']
# ['frankmellace.com']
# ['ucs.ljx.com']
# ['attornyleslie.com']
# ['merit release appearance']
# ['www.bonsai.wbff.org']
# ['loislaw.com']
# ['rapny.com']
# ['whitepages.com']
# ====================
# 2722
# ====================
# ['rentdirect.com']
# ['www.prescriptionfortime.com']
# ['staple.com' 'staple.com']
# ['www.newyorklawyersite.com' 'www.newyorklawyersite.com']
# ['westchester.gov']
# ['space.comhttp']
# ['dfdf' 'dfdf']
# ['vaniqa.comh']
# ['www.collegeucla.edu']
# ['www.elaorg']
# ['207 ad2d 530' '207 ad2d 530']
# ['broadway.vera.org' 'broadway.vera.org' 'vera.org' 'broadway.vera.org']
# ['frankmellace.com']
# ['ucs.ljx.com']
# ['attornyleslie.com']
# ['merit release appearance']
# ['www.bonsai.wbff.org']
# ['loislaw.com']
# ['rapny.com']
# ['whitepages.com']
